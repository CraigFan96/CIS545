# %%
"""
So my problem is that I can divide my dataset up into multiple parts using
the timesteps. The problem is that then the training doesn't work because it expects
a certain number of rows to match the trainY but if you add that time step, it
reduces the number of rows in trainX

If you use the createDataset/shift/padding function tho, it removes the look back number
of rows from the test data which will give us a a lower number of rows for the kaggle submission






I've noticed that taking out some features results in better MAE. This might mean less features are better
which leads me to implementing PCA. What is a good number of PCA components to keep

I read on a website that you should only fit PCA for your training set. That would
mean you are reducing the dimensionality of the training set which could mean
the model only accept dimensionality of the PCA'd training set so it couldn't
accept the test set then?

What does adding another LSTM node do

Other ways to improve NN accuracy besides stacking

Neural network is outputting same value for everything
"""

# %%
import pandas as pd
import numpy as np
import sqlite3
from datetime import datetime
import time
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from math import floor, ceil
from pylab import rcParams
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Conv2D, Flatten
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
import csv
from torch.autograd import Variable

from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
import lstm, time

import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from sklearn.decomposition import PCA

# %matplotlib inline
engine = sqlite3.connect('DB')
np.random.seed(7)

# %%
all_Data_Train_X = pd.read_sql("""
SELECT *
FROM all_Data_Train_X
""", engine)

all_Data_Train_Y = pd.read_sql("""
SELECT *
FROM all_Data_Train_Y
""", engine)

all_Data_Test = pd.read_sql("""
SELECT *
FROM all_Data_Test
""", engine)

everything = pd.read_sql("""
SELECT *
FROM everything
""", engine)

all_Data_Train_Time_X = pd.read_sql("""
SELECT *
FROM all_Data_Train_Time_X
""", engine)

# %%
#Break up the day, month, year and make them their own column and also keep the seconds thing to main the idea of time

#Start by removing the one hot encoded A, B, C and see how the model does
#One hot encode the seasons

#Maybe fill NaNs with minimums instead of averages
#Deleting store type in general

#Consider one hot encoding the store numbers
#This sort of makes a model for each store separately

# %%
all_Data_Train_Time_X['Date'] = all_Data_Train_Time_X['Date'].apply(lambda x: x[:-9])
#all_Data_Train_Time_X['Date'] = all_Data_Train_Time_X['Date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))
temp = all_Data_Train_Time_X['Date'].apply(lambda x: x.split('-'))

# %%
yearColumn = [item[0] for item in temp]
monthColumn = [item[1] for item in temp]
dayColumn = [item[2] for item in temp]
yearSeries = pd.Series(yearColumn)
monthSeries = pd.Series(monthColumn)
daySeries = pd.Series(dayColumn)
#all_Data_Train_X['Day'] = daySeries
#all_Data_Train_X['Month'] = monthSeries
#all_Data_Train_X['Year'] = yearSeries

# %%
all_Data_Train_X = all_Data_Train_X.drop(['A', 'B', 'C', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5', 'IsHoliday'], axis = 1)
all_Data_Train_X
# Out:
#                CPI       Date  Dept  Fuel_Price    Size  Store  Temperature  \
# 0       211.096358  1265.3460     1       2.572  151315      1        42.31
# 1       211.242170  1265.9508     1       2.548  151315      1        38.51
# 2       211.289143  1266.5556     1       2.514  151315      1        39.93
# 3       211.319643  1267.1604     1       2.561  151315      1        46.63
# 4       211.350143  1267.7652     1       2.625  151315      1        46.50
# 5       211.380643  1268.3700     1       2.667  151315      1        57.79
# 6       211.215635  1268.9712     1       2.720  151315      1        54.58
# 7       211.018042  1269.5760     1       2.732  151315      1        51.45
# 8       210.820450  1270.1808     1       2.719  151315      1        62.27
# 9       210.622857  1270.7856     1       2.770  151315      1        65.86
# 10      210.488700  1271.3904     1       2.808  151315      1        66.32
# ...

# %%
all_Data_Train_X = all_Data_Train_X.astype('float32')
all_Data_Train_Y = all_Data_Train_Y['Weekly_Sales']
#all_Data_Train_X['Weekly_Sales'] = all_Data_Train_Y
all_Data_Train_Time_X['Weekly_Sales'] = all_Data_Train_Y
#The next line gets rid of seconds when parsing the date
#all_Data_Train_Time_X['Date'] = all_Data_Train_Time_X['Date'].apply(lambda x: x[:-9])
all_Data_Train_Time_X['Date'] = all_Data_Train_Time_X['Date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))

# %%
all_Data_Train_X
# Out:
#                CPI         Date  Dept  Fuel_Price      Size  Store  \
# 0       211.096359  1265.345947   1.0       2.572  151315.0    1.0
# 1       211.242172  1265.950806   1.0       2.548  151315.0    1.0
# 2       211.289139  1266.555542   1.0       2.514  151315.0    1.0
# 3       211.319641  1267.160400   1.0       2.561  151315.0    1.0
# 4       211.350143  1267.765259   1.0       2.625  151315.0    1.0
# 5       211.380646  1268.369995   1.0       2.667  151315.0    1.0
# 6       211.215637  1268.971191   1.0       2.720  151315.0    1.0
# 7       211.018036  1269.576050   1.0       2.732  151315.0    1.0
# 8       210.820450  1270.180786   1.0       2.719  151315.0    1.0
# 9       210.622864  1270.785645   1.0       2.770  151315.0    1.0
# 10      210.488693  1271.390381   1.0       2.808  151315.0    1.0
# 11      210.439117  1271.995239   1.0       2.795  151315.0    1.0
# 12      210.389542  1272.599976   1.0       2.780  151315.0    1.0
# ...

# %%
#Normalizing step

"""
You have to find the right time to use PCA otherwise you are essentially
combining the weekly sales column with the others through PCA which isn't good

"""
componentReduction = 5
doPCA = False

if doPCA:
    pca = PCA(n_components = componentReduction)
    newPCA = pca.fit_transform(all_Data_Train_X)
    all_Data_Train_X = newPCA
    tempShape = np.reshape(all_Data_Train_Y, (all_Data_Train_Y.shape[0], 1))
    all_Data_Train_X = np.append(all_Data_Train_X, tempShape, axis = 1)
    scalerTrain = MinMaxScaler(feature_range = (0, 1))
    all_Data_Train_X = scalerTrain.fit_transform(all_Data_Train_X)
else:
    all_Data_Train_X['Weekly_Sales'] = all_Data_Train_Y
    scalerTrain = MinMaxScaler(feature_range = (-1, 1))
    all_Data_Train_X = scalerTrain.fit_transform(all_Data_Train_X)

scalerTest = MinMaxScaler(feature_range = (0, 1))
all_Data_Test = scalerTest.fit_transform(all_Data_Test)

#timeScaler = MinMaxScaler(feature_range = (0, 1))
#all_Data_Train_Time_X = timeScaler.fit_transform(all_Data_Train_Time_X)

#all_Data_Train_X = all_Data_Train_X.values

train_size = int(len(all_Data_Train_X) * .67)
test_size = len(all_Data_Train_X) - train_size

train, test = all_Data_Train_X[0:train_size,:], all_Data_Train_X[train_size:len(all_Data_Train_X),:]

#all_Data_Train_Time_X = all_Data_Train_Time_X.values

# train_size = int(len(all_Data_Train_Time_X) * .67)
# test_size = len(all_Data_Train_Time_X) - train_size

# trainTime, testTime = all_Data_Train_Time_X[0:train_size,:], all_Data_Train_Time_X[train_size:len(all_Data_Train_Time_X),:]

# %%
all_Data_Train_X.shape
all_Data_Train_X[:, -1]
# Out:
# array([-0.91429898, -0.85380523, -0.86653697, ..., -0.98266706,
#        -0.98352945, -0.98262185])

# %%
simpleTrainX = train[:, :-1]
simpleTrainY = train[:, -1]
simpleTrainX = np.reshape(simpleTrainX, (simpleTrainX.shape[0], 1, simpleTrainX.shape[1]))
simpleTrainX.shape, simpleTrainY.shape
# Out:
# ((282451, 1, 17), (282451,))

# %%
from pandas import concat
from pandas import DataFrame
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	"""
	Frame a time series as a supervised learning dataset.
	Arguments:
		data: Sequence of observations as a list or NumPy array.
		n_in: Number of lag observations as input (X).
		n_out: Number of observations as output (y).
		dropnan: Boolean whether or not to drop rows with NaN values.
	Returns:
		Pandas DataFrame of series framed for supervised learning.
	"""
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
dataTemp = series_to_supervised(all_Data_Train_X, 3, 1)
dataTemp = dataTemp.values
#simpleTrainX = np.reshape(simpleTrainX, (simpleTrainX.shape[0], 1, simpleTrainX.shape[1]))
dataTemp = np.reshape(dataTemp, (dataTemp.shape[0], -1, dataTemp.shape[1]))
dataTemp.shape
# Out:
# (421567, 1, 68)

# %%
def create_dataset(dataset, look_back, full):
    dataX, dataY = [], []
    if full:
        for i in range(len(dataset) - look_back-1):
            a = dataset[i:(i+look_back), :-1]#need to get all but last column
            dataX.append(a)
            dataY.append(dataset[i + look_back, -1])
        return np.array(dataX), np.array(dataY)
    else:
        for i in range(len(dataset) - look_back-1):
            a = dataset[i:(i+look_back), :]
            dataX.append(a)
        return np.array(dataX)

# %%
look_back = 104
trainX, trainY = create_dataset(train, look_back, True)
valX, valY = create_dataset(test, look_back, True)
#testX = create_dataset(all_Data_Test, look_back, False)

print('Before')
print(trainX.shape, trainY.shape, valX.shape, valY.shape)

trainX = np.reshape(trainX, (trainX.shape[0], -1, trainX.shape[1]))
valX = np.reshape(valX, (valX.shape[0], -1, valX.shape[1]))
#testX = np.reshape(testX, (testX.shape[0], -1, testX.shape[1]))

print('After')
print(trainX.shape, valX.shape)
# Out:
# Before
# (282346, 104, 8) (282346,) (139014, 104, 8) (139014,)
# After
# (282346, 8, 104) (139014, 8, 104)

# %%
model = Sequential()  
model.add(LSTM(18, input_dim = 17, return_sequences=False, activation = 'relu'))  
model.add(Dropout(0.2))  
model.add(Dense(1))  
model.compile(loss="mean_absolute_error", optimizer="adam")

# %%
model.fit(simpleTrainX, simpleTrainY, epochs = 5, batch_size = 100, verbose = 1)
# Out:
# Epoch 1/1
# 282451/282451 [==============================] - 28s 99us/step - loss: 0.0179

# %%
model = Sequential()
model.add(LSTM(1, input_shape = (8, look_back), activation = 'relu'))
#model.add(LSTM(17, input_shape = (1, 17), activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss = 'mean_absolute_error', optimizer = 'adam')
#model.fit(trainX, trainY, epochs = 5, batch_size = 100, verbose = 1)

# %%
secondModel = Sequential()
secondModel.add(LSTM(1, input_shape = (8, look_back), activation = 'relu'))
#model.add(LSTM(17, input_shape = (1, 17), activation = 'relu'))
secondModel.add(Dropout(0.2))
secondModel.add(Dense(1))
secondModel.compile(loss = 'mean_absolute_error', optimizer = 'adam')

# %%
#model.fit(simpleTrainX, simpleTrainY, epochs = 5, batch_size = 100, verbose = 1)
model.fit(trainX, trainY, epochs = 5, batch_size = 100, verbose = 1)
# Out:
# Epoch 1/5
# 282346/282346 [==============================] - 42s 148us/step - loss: 0.1869
# Epoch 2/5
# 282346/282346 [==============================] - 34s 120us/step - loss: 0.0400
# Epoch 3/5
# 282346/282346 [==============================] - 36s 127us/step - loss: 0.0388
# Epoch 4/5
# 282346/282346 [==============================] - 37s 129us/step - loss: 0.0386
# Epoch 5/5
# 282346/282346 [==============================] - 37s 130us/step - loss: 0.0385

# %%
#secondModel.fit(trainX, trainY, epochs = 5, batch_size = 100, verbose = 1)
# Out:
# Epoch 1/5
# 282346/282346 [==============================] - 45s 160us/step - loss: 0.0205
# Epoch 2/5
# 282346/282346 [==============================] - 36s 126us/step - loss: 0.0204
# Epoch 3/5
# 282346/282346 [==============================] - 35s 125us/step - loss: 0.0204
# Epoch 4/5
# 282346/282346 [==============================] - 35s 123us/step - loss: 0.0204
# Epoch 5/5
# 282346/282346 [==============================] - 36s 128us/step - loss: 0.0204

# %%
#making predictions
"""
If you want to stack, uncomment all variables with second in the name
"""

trainPredict = model.predict(trainX)
#secondPredict = secondModel.predict(trainX)
trainTemp = trainPredict
valPredict = model.predict(valX)
#secondValPredict = model.predict(valX)
valTemp = valPredict
#secondValTemp = secondValPredict
#testPredict = model.predict(testX)
testTemp = testPredict
print(trainPredict.shape, valPredict.shape, testPredict.shape)
#Applying filler cols
fillerTrain = np.zeros((trainPredict.shape[0], 1))
fillerVal = np.zeros((valPredict.shape[0], 1))
#fillerTest = np.zeros((testPredict.shape[0], 1))
for i in range(all_Data_Train_X.shape[1] - 2):
    trainPredict = np.append(trainPredict, fillerTrain, 1)
    #secondPredict = np.append(secondPredict, fillerTrain, 1)
    valPredict = np.append(valPredict, fillerVal, 1)
    #secondValPredict = np.append(secondValPredict, fillerVal, 1)
    #testPredict = np.append(testPredict, fillerTest, 1)

trainPredict = np.append(trainPredict, trainTemp, 1)
valPredict = np.append(valPredict, valTemp, 1)
#secondValPredict = np.append(secondValPredict, secondValTemp, 1)
#testPredict = np.append(testPredict, testTemp, 1)
# Out:
# (282346, 1) (139014, 1) (114959, 18)

# %%
#valPredict.shape, secondValPredict.shape
# Out:
# ((139014, 9), (139014, 9))

# %%
#Turn predictions back to numbers that aren't between 0 and 1
trainPredict = scalerTrain.inverse_transform(trainPredict)
valPredict = scalerTrain.inverse_transform(valPredict)
#secondValPredict = scalerTrain.inverse_transform(secondValPredict)
#testPredict = scalerTrain.inverse_transform(testPredict)
#testPredict = scaler.inverse_transform(testPredict)
# trainY = scalerY.inverse_transform([trainY])
# testPredict = scaler.inverse_transform(testPredict)
# testY = scaler.inverseTransform([testY])

# %%
# firstPredictions = valPredict[:, -1]
# secondPredictions = secondValPredict[:, -1]
# summation = []
# for i in range(len(firstPredictions)):
#     summation.append(firstPredictions[i] + secondPredictions[i])
# secondPredictions
valPredict[:, -1]
# Out:
# array([7217.8986313, 7217.8986313, 7217.8986313, ..., 7217.8986313,
#        7217.8986313, 7217.8986313])

# %%
trainScore = mean_absolute_error(trainPredict[:, -1], trainY)
print('Train score: %.2f' % (trainScore))
valScore = mean_absolute_error(valPredict[:, -1], testY)
print('Validation score: %.2f' % (valScore))
# Out:
# Train score: 8970.68
# Validation score: 8353.54

# %%
"""
Results:
ALL THE FOLOWING IS WITH 1 LSTM NEURON with normalization scale set to
(0, 1)

ONE HOT ENCODING STORE TYPE(Base, nothing changed):
1st
Train score: 9215.55
Validation score: 16208.64

2nd
Train score: 10934.47
Validation score: 18395.08

3rd
Train score: 10802.34
Validation score: 11542.13

4th
Train score: 7723.15
Validation score: 7723.15

5th
Train score: 9173.97
Validation score: 10674.77

6th
Train score: 10714.47
Validation score: 13530.31

REMOVING STORE TYPE COLUMN:
1st
Train score: 9594.16
Validation score: 7490.22
2nd
Train score: 8728.74
Validation score: 8728.46

REMOVING STORE TYPE AND MARKDOWN:
1st
Train score: 8054.40
Validation score: 8054.41

2nd
Train score: 9472.83
Validation score: 9661.53

3rd
Train score: 9260.64
Validation score: 9260.51

(With 10 epochs)
1st
Train score: 10192.43
Validation score: 11483.70

2nd
Train score: 9984.86
Validation score: 9984.73

3rd
Train score: 9649.48
Validation score: 9649.48

REMOVING STORE TYPE, HOLIDAY AND MARKDOWN:
1st
Train score: 9498.86
Validation score: 8269.08

2nd
Train score: 10376.39
Validation score: 9146.57

3rd
Train score: 9990.98
Validation score: 9105.79

4th
Train score: 7504.94
Validation score: 7504.95

5th
Train score: 10163.71
Validation score: 9188.98

6th
Train score: 9827.79
Validation score: 8204.84

7th
Train score: 7487.19
Validation score: 7487.20

8th
Train score: 9600.01
Validation score: 8681.28

2 LSTM Neurons for removing store type, markdown and holiday
1st
Train score: 10900.66
Validation score: 10191.63

2nd
Train score: 10974.74
Validation score: 10256.22

REMOVED STORE TYPE, MARKDOWN AND HOLIDAY WITH PCA components = 5
1st
Train score: 11809.17
Validation score: 10781.34

Train score: 11725.98
Validation score: 10736.46

REMOVED STORE TYPE, MARKDOWN, AND HOLIDAY AND ADDED DAY, MONTH, YEAR COLUMN
1st
Train score: 8353.67
Validation score: 7632.65

2nd
Train score: 10476.60
Validation score: 9347.11

3rd
Train score: 10436.40
Validation score: 9295.82

REMOVED STORE TYPE, MARKDOWN, AND HOLIDAY AND ADDED DAY, MONTH, YEAR COLUMN
WITH PCA = 5
1st
Train score: 10294.58
Validation score: 9376.57

REMOVED STORE TYPE, MARKDOWN, AND HOLIDAY WITH REGLULARIZATION SCALE
SET TO (-1, 1)
1st
Train score: 8970.68
Validation score: 8353.54

"""
# Out:
# '\nResults:\nALL THE FOLOWING IS WITH 1 LSTM NEURON\n\nOne hot encoded store type(Base, nothing changed):\n1st\nTrain score: 9215.55\nValidation score: 16208.64\n\n2nd\nTrain score: 10934.47\nValidation score: 18395.08\n\n3rd\nTrain score: 10802.34\nValidation score: 11542.13\n\n4th\nTrain score: 7723.15\nValidation score: 7723.15\n\n5th\nTrain score: 9173.97\nValidation score: 10674.77\n\n6th\nTrain score: 10714.47\nValidation score: 13530.31\n\nRevmoing store type columns:\n1st\nTrain score: 9594.16\nValidation score: 7490.22\n2nd\nTrain score: 8728.74\nValidation score: 8728.46\n\nRemoving store type and Markdown columns:\n1st\nTrain score: 8054.40\nValidation score: 8054.41\n\n2nd\nTrain score: 9472.83\nValidation score: 9661.53\n\n3rd\nTrain score: 9260.64\nValidation score: 9260.51\n\n(With 10 epochs)\n1st\nTrain score: 10192.43\nValidation score: 11483.70\n\n2nd\nTrain score: 9984.86\nValidation score: 9984.73\n\n3rd\nTrain score: 9649.48\nValidation score: 9649.48\n\nRemoving
# ...

# %%
#Should have 115064
testPredict.shape
# Out:
# (114959, 18)

# %%
formatAllDataTest = all_Data_Test.values
formatAllDataTest = np.reshape(formatAllDataTest, (formatAllDataTest.shape[0], -1, formatAllDataTest.shape[1]))
print(formatAllDataTest.shape)
# Out:
# (115064, 1, 17)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-202-d9f2d8dec2e8> in <module>()
#       2 formatAllDataTest = np.reshape(formatAllDataTest, (formatAllDataTest.shape[0], -1, formatAllDataTest.shape[1]))
#       3 print(formatAllDataTest.shape)
# ----> 4 model.predict(formatAllDataTest)
#
# /Users/CraigFan/anaconda3/lib/python3.6/site-packages/Keras-2.2.2-py3.6.egg/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1145                              'argument.')
#    1146         # Validate user data.
# -> 1147         x, _, _ = self._standardize_user_data(x)
#    1148         if self.stateful:
#    1149             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ...

# %%
all_Data_Train_X = all_Data_Train_X.values.reshape(1, 421570, 17)
all_Data_Train_Y = all_Data_Train_Y.values.reshape((1, 421570))
all_Data_Test = all_Data_Test.values

# %%
# model = Sequential()
# model.add(LSTM(
#     input_dim = 17,
#     output_dim = 1,
#     return_sequences = True
# ))
# model.add(Dropout(0.2))

# model.add(LSTM(50,
#               return_sequences = False))
# model.add(Dropout(0.2))

# #Becuase problem is regression, we need lienar activation
# model.add(Activation('linear'))

# model.add(Dense(
#     output_dim = 1))

# start = time.time()
# model.compile(loss='mean_absolute_error', optimizer = 'adam')
# print('compilation time:', time.time() - start)

# %%
#model.fit(all_Data_Train_X, all_Data_Train_Y, batch_size = 100, nb_epoch = 1, validation_split = .10)
